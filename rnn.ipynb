# %% [markdown]
# <a href="https://colab.research.google.com/github/karankulshrestha/ai-notebooks/blob/main/rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
data = open('sample.txt', 'r').read()
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)

# %%
print(f'data has total {data_size} characters and {vocab_size} unique chars')
# Out:
# data has total 6661 characters and 66 unique chars

# %%
char_to_idx = {ch: i for i, ch in enumerate(chars)}
idx_to_char = {i: ch for i, ch in enumerate(chars)}

# %% [markdown]
# ![RNN training diagram](https://d2l.ai/_images/rnn-train.svg)

# %% [markdown]
# # RNN Architecture Example
#
# **Configuration:** `vocab_size=5`, `hidden_size=10`
#
# ## Forward Pass Flow:
# ```
# INPUT: One-hot [0,1,0,0,0]  (5 dimensions)
#            ↓
#        [Wxh: 5×10 = 50 weights]
#            ↓
#        Combine with memory
#            ↓
# HIDDEN: tanh(Wxh·x + Whh·h_prev + bh)  (10 neurons)
#            ↓
#        [Why: 10×5 = 50 weights]
#            ↓
# OUTPUT: softmax(Why·h + by)  (5 probabilities)
# ```
#
# ## Weight Matrices:
# - **Wxh** (5×10): Transforms input to hidden space → 50 parameters
# - **Whh** (10×10): Recurrent connections for memory → 100 parameters
# - **Why** (10×5): Transforms hidden to output space → 50 parameters
# - **Total weights:** 200 parameters (plus biases)

# %% [markdown]
# # Batch Processing with Memory Continuity
#
# The RNN maintains memory across batches by passing the final hidden state forward.
#
# ## Batch 1: Process characters 0-24
# ```
# ─────────────────────────────────────────────────
# Input:  hprev = [0, 0, 0, ...]  (blank memory)
#
#         char[0] → h[0]
#         char[1] → h[1]
#         char[2] → h[2]
#         ...
#         char[24] → h[24]
#
# Output: hprev = h[24]  (memory of chars 0-24)
# ```
#
# ## Batch 2: Process characters 25-49
# ```
# ─────────────────────────────────────────────────
# Input:  hprev = h[24]  (memory from batch 1)
#
#         char[25] → h[0]  (using h[24] as hs[-1])
#         char[26] → h[1]
#         char[27] → h[2]
#         ...
#         char[49] → h[24]
#
# Output: hprev = h[24]  (memory of chars 0-49 now!)
# ```
#
# ## Batch 3: Process characters 50-74
# ```
# ─────────────────────────────────────────────────
# Input:  hprev = h[24] from batch 2
#
#         char[50] → h[0]
#         char[51] → h[1]
#         ...
#
# And so on...
# ```
#
# **Key Insight:** Each batch "remembers" everything from previous batches through the `hprev` state that gets passed forward!

# %% [markdown]
# # The COMBINATION happens INSIDE the state update:
#
# The hidden state update formula:
# ```
# h[t] = tanh(Wxh·x[t] + Whh·hprev + bh)
#             └──┬──┘     └───┬───┘
#             current    previous (hprev)
#             input      memory
# ```
#
# **Key insight:** We multiply `Whh · hprev` to transform and select which parts of the previous memory are relevant for the current timestep.
#
# **Components:**
# - `Wxh·x[t]` - processes the current input
# - `Whh·hprev` - processes the previous hidden state (memory)
# - `bh` - bias term
# - `tanh` - activation function that squashes the result to [-1, 1]

# %%
hidden_size = 100
seq_length = 10
learning_rate = 1e-2

# %%
Wxh = np.random.randn(hidden_size, vocab_size) * 0.1
Whh = np.random.randn(hidden_size, hidden_size) * 0.1
Why = np.random.randn(vocab_size, hidden_size) * 0.1

bh = np.zeros((hidden_size, 1))
by = np.zeros((vocab_size, 1))

# %% [markdown]
# # Gradient Flow in Backpropagation Through Time
# ```
# dh = np.dot(Why.T, dy) + dhnext
#      └──────┬──────┘     └──┬──┘
#      │                   │
#      │                   └─ Error from h[1]→h[2]→h[3]→h[4]
#      │                      (future timesteps)
#      │
#      └─ Error from h[1]→y[1]
#         (current prediction)
# ```

# %%
def loss_fun(inputs, targets, hprev):
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)

    loss = 0
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size, 1))
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh)
        ys[t] = np.dot(Why, hs[t]) + by
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t]))
        loss += -np.log(ps[t][targets[t], 0])

    # calculations of backward pass

    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0]) # override it not accumulate, pass the gradient of loss w.r.t hidden state from last input to first during backpropagation

    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # dy = gradient of loss w.r.t. output y[t]
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # How much does the hidden state h[t] contribute to the overall loss? h[t] → y[t] → loss[t]
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)

    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# # Random Sampling with Probabilities
# ```
# np.random.choice([0, 1, 2, 3, 4], p=[0.05, 0.10, 0.60, 0.20, 0.05])
#                  └──────┬──────┘     └──────────┬──────────┘
#                  pick from these     with these probabilities
# ```
#
# ## How it works:
# - **Indices:** `[0, 1, 2, 3, 4]` - possible character indices
# - **Probabilities:** `[0.05, 0.10, 0.60, 0.20, 0.05]` - likelihood of each
# - Index `2` has 60% chance (most likely to be picked)
# - Indices `0` and `4` have only 5% chance each

# %%
def sample(h, seed_ix, n): # h-> prev memory state
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %% [markdown]
# # Adagrad Optimizer Update Rule
# ```
# param += -learning_rate * dparam / np.sqrt(mem + 1e-8)
#          └───────┬──────┘  └──┬──┘   └──────┬─────┘
#          standard SGD     gradient  adaptive scaling
# ```
#
# ## Adaptive Learning Rate Logic:
#
# - **If `mem` is large** → `sqrt(mem)` is large → divide by large number → **small update**
# - **If `mem` is small** → `sqrt(mem)` is small → divide by small number → **large update**
#
# ## Components:
# - `learning_rate` - base step size
# - `dparam` - gradient (direction to move)
# - `mem` - accumulated squared gradients (memory of past updates)
# - `1e-8` - small constant to prevent division by zero
# - `np.sqrt(mem + 1e-8)` - adaptive scaling factor
#
# **Key Insight:** Parameters that have received large gradients in the past get smaller updates (more conservative), while parameters with small historical gradients get larger updates (more aggressive).

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by)  # memory variables for Adagrad

smooth_loss = -np.log(1.0 / vocab_size) * seq_length  # loss at iteration 0 -- initial random loss

while True:

    # Reset RNN memory and data pointer at end of data
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev = np.zeros((hidden_size, 1))  # reset prev RNN Memory
        p = 0  # offset to the data

    # Prepare inputs and targets
    inputs = [char_to_idx[ch] for ch in data[p:p + seq_length]]  # input characters
    targets = [char_to_idx[ch] for ch in data[p + 1:p + seq_length + 1]]  # next characters

    # Print sample every 100 iterations
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(idx_to_char[ix] for ix in sample_ix)
        print('----\n %s \n----' % (txt,))

    # Forward seq_length and calculate gradients + loss
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = loss_fun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001

    # Print training progress
    if n % 100 == 0:
        print('iter %d, loss: %f' % (n, smooth_loss))

    # Perform parameter update with Adagrad
    for param, dparam, mem in zip(
        [Wxh, Whh, Why, bh, by],
        [dWxh, dWhh, dWhy, dbh, dby],
        [mWxh, mWhh, mWhy, mbh, mby]
    ):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8)  # Adagrad update

    p += seq_length  # move data pointer
    n += 1  # iteration counter
# Out:
# ----
#  ?AY)4.; yB2-HLIbPk
# rf:i;Y(w3gsxUNS(a.1:UGmd;m;3meghxu6yAI9sYfy,0Ot);65,YbFqNaq2TsRtaxbUjOR;coB18je:MI?WM3k2t7uclj5BBOyTzjrh1gDvyh.a0j5azg9)sRFYRb:TUCBLHGc8mUBPN:T(Mo;UYRR'gD5LaML.iedWUn8(of25gy83gcvM8
# ----
# iter 0, loss: 41.897431
# ----
#  ' blasarei e Wonpa dpd Tslee w'e T o,a:teet enegr,  iyTl-heketat ioi6ehehWaueteu1u o
# e'unT rareh,a H-heeesdoi' re l(ns v
# ossWSt  T Wwle,u   dae
# eeTr 1ngeh
#  eedstsat ehe u
# lyeioeypbealsnnhivfbCn,aoo
# r
# ----
# iter 100, loss: 40.837761
# ----
#  m rpmm be ha t  a e s t r ewom  sfhbme : g  det
# nc uoes ai aiit,  w  Fd  el hwssy  is iheehpg
#     ul
# .edeee  i:  iw eFbnn
#
#  t lh  c yaeg   ose   edi w  cyteei
# e  eht ,s  s ehio ei n hg  tniocse  si
# ----
# iter 200, loss: 39.689422
# ----
#  esctew,gh(oLntee e  ir  hhb lga7th hi T,told lhvnyt;nu
#  ,radfot oxf res thpHey  Ftswetsfoht t o2t emm  irei uae yswsase,otvuch  ew Tl Af is
# ho heen nIlau
# eisnusu uunte gB5
# eamaht yhuyhOe m mbpNe sove
# ----
# iter 300, loss: 38.655627
# ----
#
# owsf
# th
#   sWy iiefhe  tna anhui tveio n usv ie  ths  gacek hf  rrn e  ee  v
# eL   ming  h   Tu u?  itme  hos :b  :s   t is
# f ra h Pe sre ve   x.t    t cro t vewh
#   so it g  siel whe  oav ,   tir  aea
# ----
# iter 400, loss: 37.612951
# ----
#  eftihos ooglthun.
# t  reta dehhl
# cduToin tff o  mvmshh'tt
# fe ydeucinw
#  htr  solsnh neoe det lgino noane therewlettussofnauhe lucolta'v sceidua  on r rho use ;rodhest sonuhs Aon so
# d rhatoo rsutea
#
# io
# ----
# iter 500, loss: 36.761700
# ----
#  io  eylktsy ,l ts  o se  ir t e    s ohlhcu ;ihe s eyl  r ld mte   U  cnekhnme: i  sislytu tht Tn fhtu miy ceh
#  ilidtah't yis w,e,  r y ra eyyoe iry w oow fnt  fa medes   ya  nops oin istbu  os  n ehn
# ----
# iter 600, loss: 35.891233
# ----
#  eladptPoed,o
#  Iham ,f fTmh  s'sdyr:noorige ieitss,,: e,
# h hhelth su
#    i  rsiu2 gdite
#
# dsl ?  oan
#   xm tthhaueiifeat  viitt anaesud ra   o aynlleecthe treae t  u  'i;
#  le f
# hoo y
#  ag, tefmr  eadual it
# ----
# iter 700, loss: 35.016708
# ----
#  a   ys  eooem
#   ther  rhtben ow uho  e  gvy Tlebgh
#   oes  win2 wnh   uanae'i   o ld th oh re ns  fawgiwh u,  ,en .a bysrootr n'  ndu 'tid co eser  iadlyclut  li  ha
#    in ;oo toir
#     eaed hhe isd   o
# ----
# iter 800, loss: 34.179281
# ----
#  ,Dayty yimeuwim  gvyu fig  sovs  ol dhes lhe
# e solhune,e  rnure segt,og nhes, rocp roet  a w' ,  unld
# ybesi   cna leou le tndrvenute
# r
# z aileyesiduifvf wo mrrlsesTuon totdm.at ,eam  aas,
# s Rhosethnt
# ----
# iter 900, loss: 33.355606
# ----
#  eho  r dthh  eonr
#  w te eees:ves  ire veelym-one  iheuhetsuue r
#   ui
#   ywpbeit  re u
#    ona areuts ghu h- yn e
# m wh,teto legto  wed eSit choe  io :rrlS;in
#
#   h dno eh se  hn lh t  te
#   peetn
# 6boA he
# ----
# iter 1000, loss: 32.650667
# ----
#  he thel ddo
# w  s n
# snie saw t ngspwitene toui,i   ir airea
# e blediv4oesnt lard thnltbr  heim setsn cefoi t id whe  ahd
# p  eni
# h govabe  rnAs  hanw inas  tomusmtuiirnc,lt rmtheloail  rai,  mhe sBn lga
# ----
# iter 1100, loss: 32.006211
# ----
#  p 6htii Whb hhe enat v thld t
#  r w
# w bh ht  bdn  a gla thth noge thew y OF  2 cor y iho o fhet oS  o     a  ie  hTth mn  cB
#    lo 'h lgasbeneendo  ho
#   To    toy uanu certemauilrgs og t'a t LoW  o t
# ----
# iter 1200, loss: 31.453136
# ----
#  r virieyasn ,atgratp bi msig,witheetasy e e tun oha  toreyoia(i ln zeptb
#  mese tht cWathoc
#  aie sisthe'f oa
# feF ioetonememe trdd,nrre tnr whe  he f thoweohf6 measb thy ,a  bemt tha woistpaufnileea, s
# ----
# iter 1300, loss: 30.855455
# ----
#  i
# t gi  ie s  ro re
#   eolnntmrnlon ko thyot so'm in, t,hr  he leati dnf le fhb w
# l fhvlbthe he,i
#   ey t  u vu nucu Mite soe ehe  sytlter mntsest pe t nt0 fot f'-  peuftithuthtn
#  fe ln:
# l  hgntla teg
# ----
# iter 1400, loss: 30.281003
# ----
#  yas  s iso tiyss yfmensst in woa s of ni a  te  ih  i'a  oos tBe tTedm nMecpthd
# w sr t,
#   Thkd teseutr so  ,e  oirlrseeh to rin:nedeause loo thufweso,u 9e u
#   Aod theky:low?eserenf  klselnwddlududlne
# ----
# iter 1500, loss: 29.730544
# ----
#  s s cMic durl we
# teal fntehaae,
#
#  k.o   o,e sot tda ll gef- oaec
# s,aiL.eet be:pe ,
# o Deee3e  tzlctberefwahe,  aof lh -  s
#   iha  hotn
# s ahegy nr thit be finhr
#   neiAep anv th ufli
#   Be lh prd b cs to
# ----
# iter 1600, loss: 29.154276
# ----
#  rensr theu
# tethanberaf;otlltmthrreotawwior taemssoie doeesuge bsa too
# eweette'e blengiety rofhro riid toe w
# e
# b aoet wonw rhaullra tuitfrung,Is to  et tithst i t
# 'c mo uhet
#   L  hoseantfeartrsr n:e tl
# ----
# iter 1700, loss: 28.721215
# ----
#  guei,
#    Melf wvb lray woro
# d,ruweot dow mee sefchgsyther dofe th
# leoherktophlrey li ,th th t qeml? pt  he s  T  cc  heo
#   Aingortonwcwsaditinl neru  naves
#   Wo
#   ThMcttrtbsu rvtmugheulthet
#   f bed
#
# ----
# iter 1800, loss: 28.365659
# ----
#   th thyrls th  sall-sleys ein,
# w Thuh:nhy, ,ellle bnnAllldtnt
# o whtron she, raNthess eeWmtletcam yon,-peees  snd ergd giee i. this ctie  rowlthv gTw  s y'tr fdou qheseafrast nouaswodtho warv fnee'ses
# ----
# iter 1900, loss: 28.004701
# ----
#  ese topbeoreaturtouotddbeys ir  eeuorle oiptthen  reelemorsetetytthibesrnnn o corlt
# lw-mnth nium ti thes tithytht .mec,ed lloggbetva
#   g .e ensstmhiun,e  sneei::lwnsle salw nele ehanatedttlesptfwowdht
# ----
# iter 2000, loss: 27.610060
# ----
#   oue,'i onsg
# b cantssit , fiunsegd m,ea qoe cke tond thy  trt ir  hare,
# no
#   e aenmrp imh-  ivty.y wesf,t  Onsierdeuds'mea gItep  f ur liresheag l or,t  e(He
# s  ofito
# asthys.tl, -haonls en  hy
# th ba
# ----
# iter 2100, loss: 27.253618
# ----
#  heos
# o  le aig dcreeif aneupedy bo io   ilg thed
# r  ois
# h flf g o0e h,  d' f  oo  and lo :o
#  oc gh fwin,t an atr tecotb ep th   vet bh,dpase sh tui2 som os  theyA
# N    l
#   hg  oeas
#   W  rn s  - s
# ----
# iter 2200, loss: 26.842515
# ----
#  tite fhel traftslomes' thgunyeoetmive w a  hdy be wennou eoes
#  Loothisepfsteind -semi weee feeli A
#   9irC wis ,na.ys the  eid:Fn nhe toe,wila inlom de,m malforndv'f nh thrish thruthendsatceefYrs8tla-u
# ----
# iter 2300, loss: 26.515257
# ----
#  neee  bereth s reTe therthine ,k eyaders wettustthey rerecaten
#   b tuelu se,h
# l
# lFth boy :he tio  iM bithoue
# abtnpe iutocp ftd tcouot,ou the teate
# ' mka tbeprire,
#
#  dh Ilrq
#   ors t mamd,
#   Theesm th?
# ----
# iter 2400, loss: 26.184335
# ----
#  y saf  roydbelcefino, uy  ho foeeisnda nfeat i nhyr,s  eo  Oh   or we: -,u tho hhttakhl'y ring-thrr shtPlese,tremtyeine p
# ord toan wideautee thann salc lte ou  iuadstiate n,f epthle urtrs -onheymagees
# ----
# iter 2500, loss: 26.043362
# ----
#   bhd
#   Tit fenn fMeuy toate,gelW n d do f  t it thounlawde
#   iwel
#   Str sis f sdrl thlmiwe iod thafeonlasemetDon uirt,or pomu dau hre e ;astsiglttle foer sln naopn slloo,lt lofltt arochn se der r
# a jo
# ----
# iter 2600, loss: 25.794421
# ----
#  b.n nolver  ontrreefsiuh  norecignPx shas
# y s ae bbsd snygiv nbarwt ui e,
#   Sht: d boagep nerdcr
#   e thy chepsoae vo en ke,g FSe eirnCsdowedbcen
# s s vuea feel why  oTl ro ,cr th'l'sstgores thercs re t
# ----
# iter 2700, loss: 25.548140
# ----
#     eoe whln Ain sr ntmovgoutho sh th;sc eud chld tto'o ror kid   ouldst taats  Touaeaedege  in   c5 garerwengbegwrnlmsaru'w thtee,
#   L ss t oue fssa Hso tocop,ae lge tuoe the go  hic? ,o  Ao s  oeke t
# ----
# iter 2800, loss: 25.278367
# ----
#  tptherurMrti noobgssls the t:lateel
#   aheth we v,  hn t:iu-a:t nh swpunuststbd she the shevst repiog  hoee,
#   Sr co ile 'nehe then
#   atnsmenemltenflt sh  racot dotum
#   Io ka.pseathe shmkldeeupeak revl
# ----
# iter 2900, loss: 24.994845
# ----
#  so waare'a ceg buiy to  feome wonso beol,t
# o   r0  Ii mhps bB
#  ir both'u swrerrst  n y th wwedc taot nelrnr,
#   T y theg ths mont wee t
#   WAmu th in  Won toMere tute thiu wsyntup,  hTsune woase aoe in
# ----
# iter 3000, loss: 24.783092
# ----
#  t cn not thsu Aht boet,ep wivli,,
#   PN0  ra in whan,l vlr dhrmeoiiswslo ,ee,
#   th h:r thlv,v bTeh-nw Cod sheuttheroildrpne tosdawiamf'rivvth
#   herg
#   finhl
#  ei he wiou  la shend wer lin 7Mreur  b,t
# ----
# iter 3100, loss: 24.644211
# ----
#  neale thuWdrld bined
# o  hohelwene
#   0n le se dis d
# c   a bleci kseeb  inugedhun phov  oov yib so fin soor  ath ialttohis,q  necb,he debunulla r nit  ureedlylecn,d bnwnerecaswsothi en t
# e gby Ie  bec
#
# ----
# iter 3200, loss: 24.513936
# ----
#  vwwtdesed  heres-watteale'
#     Au tharlco ee sg'lg dfot  ao leruwdddses lr xig,
#     Thlnwyepanig
# e  r  tire h're aave tvoukadotetd tooh r'uth mianst wieit
# y shetheu toricosptDm somfotha'r rld birono p
# ----
# iter 3300, loss: 24.334160
# ----
#  et alivlafeeen
# l 'hithplanucrless
# f S  rpt mrelefsagg
# b sereetsonthey'bgtedt ohnThr
# m fheb' w whis tedki
# h th  no,
#   Thor bnerd uile mo: lh tatk  nfeseueen th  ast tioudets ine
#   Or  oo
#   F rd Beth
# ----
# iter 3400, loss: 24.141089
# ----
#  ledas ahere prnds snebd
# s  loeenflg:ris xiafl ahoe ther?  2ar non'da
# f
# h no rh'u wothrellou wedlss  Ay  ou thu:  nr th a th uhang  Se the'y sien, s Aile mr doe dond deaar retof mod s-sureet lakerc nt
# ----
# iter 3500, loss: 23.962284
# ----
#
# e wn an witees
#   Wen tha
#   ihasylstupt.lt uo, so hac lory suwalt,
#     ft   he  brs tal-,
#
#  -  ihe thof tee tooft  l sHe
#   s M tic so thesteouesdsbrudhanihipcone the eaftivg afetiweufwpmo d f  t to
# ----
# iter 3600, loss: 23.732925
# ----
#  e6wllti,t  rinis eo the sa p tos
# u  one s on  le (in  seeien goig  worth
#   Iee me bced tin,p dueapt e aut ls  nleebifh?e  raar- noon bngfthet  neutrhe  hthopLomen.:
# e th
# A thel ,
#
#    la weo theas Ise
# ----
# iter 3700, loss: 23.607045
# ----
#   wadchen ir, laagsdwente
#   - as  sie cea
#   lhett cetscia g woriieetisthi:l yNy miv  eoiseelw whee tunngphord o  eot  hol  f mnoIr iundemuver ghvd thy moop areo gimg leauBggav,ot lr Air ,b ncmy ,o mo k
# ----
# iter 3800, loss: 23.561617
# ----
#  ue atacmrwau' aizadthe fmek  fath thapd st hls teatos waedd
# t Thoreltmahe love uon oi dher phat anve crenix pha ioudstin's so'  on tond tonh,b  Bho ao  hyh
#   uer ba dels Sir7serlwsilv
#   n   k  tiu th
# ----
# iter 3900, loss: 23.478918
# ----
#  mutl tiow tarftnam bfe'ig eihe hercdsd rtiar eaou,ya chet nondetp taoulon ghleudt ina:ise sagior iny fLndae,fblhayrintherofriml
# t Foare paw,
# M Wh d thch thecm shicelethokl  iithrennt, flert oa teis  A
# ----
# iter 4000, loss: 23.334005
# ----
#   wisot domadnwentteit  oeufthol'
#
#   aoet
#   oo d
#   Meay perus tne lalhg
#   Sinelisd thiveshfsd fr thy naawt  he 'he toag raal sfoutsos bnasd nevhiupeto dtyr  opcesepbeoote,w in sulft
# e 6ting  erlstf rho
# ----
# iter 4100, loss: 23.219819
# ----
#  tu meningtnt  Pa so nereke t?
#      nr dosd
# l thaut ar  gole the gkntvms dniwdosthamed
#   Gk s tor sto
# :oy witth'n dfmage,
#   WiUen thylnhrel caa
# s
#   O  io gososc wing d whe trs fne thasy sojuthy naaty
# ----
# iter 4200, loss: 23.029982
# ----
#  se die saneinr poe ule  rstoye tane  ager vnthydsnd,e fh?r  Teousugliver thing  leus siwf toee,
#   Yerusslithes  'hr qantfnthedgot tnouhinvwa te  le thet covdrrdeinlowtee wecchts tone weathdcengt tint
# ----
# iter 4300, loss: 22.920273
# ----
#  reunelkeotdeguarele,
#   Me eiep
#
#     Thy  fhwr ain kh d 2he toldis weli vevfnathiee,
#  An thet  aou thrss dor te t l at linT ree ,o  ar g se,o2 woPst dil doserfqtherltwdan sone e c le thous lig s
# d  o
# ----
# iter 4400, loss: 22.784122
# ----
#   wfon oamd thon wats  are ffeeee
# e enfre  he d eoes syedatn oe  to tu' thas ?effe t
# s sh tyTown uor tone,
#   geet ing houhy wowu be ewf lo Lar,
#   Solt alistton of'sr memh
# j
# he  aad thite nr ouheld,o s
# ----
# iter 4500, loss: 22.831020
# ----
#   th3utewines
#   Ting  he  hy taylls thy thy 3eatned oorea,  hoe thy wother  nl
#   jhM  ult toildwestilasi
# f e  fved apmuavd wnelcp,y  of bibs thingtino gkohone.
# s  he  wf tedenplr
#   I ll chy  Gra.
# n  ho
# ----
# iter 4600, loss: 22.731570
# ----
#  t beni,n ranle wemuge dhenp, theu nd ti fs  nad tot nol waatgen shou sFurepshen?
#   B efpreinhe wsris reest
# d soalcyetls ,p, t o cer thynptpre weaty cfefuth ou s4old khan bfte to
#   o fthf the tiau thou
# ----
# iter 4700, loss: 22.638601
# ----
#   Teyh
# n :a uredw,   awe t wes thimewettyesand s?ef thaucunhir  hkofteo  ring thy soory
#
#  f  u  y ou 8last ginsllt hrlayu
#   A m thl  ouamuremsnedusta lt set toa dechyow,ls wais 'he towat tuoth
#   b toil
# ----
# iter 4800, loss: 22.502807
# ----
#   hiug elei
#    iaut bheln sir,
#   Ieg,
#
#   he kemtw
#   AnTtl oud .a tyad fmedisenet yus  2oou srtin thivi tj
# t n souc tne feeu
#
#    Doeldo s them cingg ciyes  Sogl ne bed indthy tioul apriik  sote mrmuar,
#
# ----
# iter 4900, loss: 22.347863
# ----
#  sure ton,
#   S Thi lr?imgdtrovetesube ses wapnoch:se god ceaplel,
# r Budbinew ty bene ahe toey lateegsule rhrk  ndoal:ieg'ahe relg 'lt the cafrdes  unBciar?'ate  anon lese:Ctgaat,
#   Theuithetuanhe
#   Phe
# ----
# iter 5000, loss: 22.286698
# ----
#  to ceams
#   Ol meomthe mot  Wn frwit:e  fjthcunaoh t-ylculu sis  oii   in ch aeueec wonth'uy reafthit  ,aat ue sis  tha thsh prrat  oo  on sind thve sthmus:
# n  on toneeeir xhe  fale  uot  erews nf fp.a
# ----
# iter 5100, loss: 22.275777
# ----
#  thene while dbseh to the woof anlea
#    Sot telaive,
#   Ti e
#   TonlTheitt iug  oine sone,t ihet dharethy tir  toor waglise,
#   de tt ,Boxeero hor wor steyvbe tnr dr crddbteigstin  neaed inte thoos aorin
# ----
# iter 5200, loss: 22.249030
# ----
#  rt,
#   Tne shin  han telrlB wichtow thing?
# t were aseaslra
#   o  oo  ontsbt  lr  ?o wheb: o
#   d eh ohoutwyte she cing tyithi merhc nete b?aofentewcut ne timl prem bolise thBo thec,
#   Os hh  d dir thymy
# ----
# iter 5300, loss: 22.173109
# ----
#    phou ir jalf the  arabd dy cisu-rofphiw bedurlnopls,
#
#   S ald wx ndtrand saat -n
#   ?   rou lr13mes.ar,e qg banene,
#
#  B1
# b gk tired theg and the
#   werlngwuklhe  Bi;l:,  dad laoreecmdssilpuglarzogdc
# ----
# iter 5400, loss: 22.074694
# ----
#  t theuver thy le biy:
#
#
#   L  the  Weth
#   on tink m
#   the  f thiuls nle,iqr fee hh tle nhy qosesenW sighle he :r dh thoutht pooed su hos ipreis th6sc, r fl ,
#   f bo :cicl'p lee roe fhwes ingt whene
# ----
# iter 5500, loss: 21.986814
# ----
#   yy sanl  winll
#
#         s  aos endss  Bresd
#
#     oi  hale seea
#   Y.heu- ule woale dudos cauf thy sres.
#
#   Pi  he   ore  ooketb tig duad mot lodedes pyeDu'e 2iwhdibe sorepor s ghpcestey sracinrtel ury
# ----
# iter 5600, loss: 21.825703
# ----
#  renteint.l wDrhe,  oaalist kive:
#   De u se teanpu ceauiund wetu ye gy?ty
#
#    h  s
#   S os  vemutety bmssy solodl  oou darinthoskeob tilse  enuth  ty ton saseiftpt waad theu tlou iagee be asoslewfdt i
# ----
# iter 5700, loss: 21.782371
# ----
#  ingodsgit scyusd aWiye:aehutho fadlith thndegtius l'e teug'ne iee, wilg anehduns chy sit nnd sto wattBeuwnety ehe
#   WWathep uin,Wk -aat foayg unwerti  ie lir
#
#   o  kis lre  aresdr ding bwive'e bh eew,
# ----
# iter 5800, loss: 21.820617
# ----
#    Hos  iut ea th  f che f lfirge dere,
#   BiDoth tdein,
#   Gencrh -i:e,
#   Tha lWip,y weace syevet neselsgAon th'u  ona- soth thn rand bonicry
#   erCbi d sanc
#   frtvethy aeablmwkthy noar,
#   Rhet comes wye
# ----
# iter 5900, loss: 21.816270
# ----
#  ot guthy rortcanutitl  arrrhihe theth reis  outhen,  ntreqtigupesofoor  tom tomndeen aro  uaif eluctinss noa doob'salf the  oondsbinmalingg togelrymafto
#   sid rorbof ines .uln the bu'pcy apoait tooisn
# ----
# iter 6000, loss: 21.724423
# ----
#  ythy sseired 8nDiaen basriad  'ciun toy Iead gh lTy.s kvath beee
# u  hou best yevemm ter, t dy thy thon nTithald tiluty winre astnMau,
#   O whot ru dond shoresdirgo'k n vy te tynw wan eem Oic-,angir 't
# ----
# iter 6100, loss: 21.676323
# ----
#  r theu hy sneeile,
#   Trok maln s shot ceatt wonn te,
#   Tos  himen sf col te tcy someni tint
#   oth thenrs-wshs kbeae,
#
#   at t, dftoy wocoud roagceie thy sse thin arefmrreittyo
#   For  rethbpessrs'y sou
# ----
# iter 6200, loss: 21.530760
# ----
#  arb lous thy.qurserauf terfaut are foel seavere beart loabesiad sonhabe:aim livere toiu ouodit7 an, th thy snit anlotf foun.
#
#    or beiee doutjla weuu noud thin th'ov.asthe sedcsnmssd srarfgol bulla?t
# ----
# iter 6300, loss: 21.475943
# ----
#  th ndtremeinR
#   Bim thep thou :hebe,
#   le Deeas lf that wiae thyufn:d woecn eiathyts theuc'rwmtt thbanatn'e fild ghfeeallw'srelwint  nap if phecerymun thiu?ha  inln wiair ceace dyrllebe,
#   B; bobeeet
# ----
# iter 6400, loss: 21.402131
# ----
#   lowero'd da1ty sevf miree, aAst (utei'r thar  auel
#   Motedthe wey tidd thy beri gPar; rhe thy sothyesthar,
#   Faceist intiil  heth'  overebedipgl cTelf fntusy pie n thupralt hame fale trlenda
# S  hcuna
# ----
# iter 6500, loss: 21.491853
# ----
#   wolunqtmp aufur bismerss th ces inlt
#   FelosAlr-gothlssurld senes the ithe fawrlo hapdiving wntt roae.bs;
# o  h ne s thib thoueveru, 'h unk aile don' ying sn niwhol -umat siket
#
#   N  ho  wort yor antm
# ----
# iter 6600, loss: 21.417563
# ----
#  d hint,
#   Tnauy eiat
#   daos wntctn
# f merels tlmon rhersssmeluthass thin witremv-llomthf rofarind oomf dovf wor ereai' the the thot ?us tiaut
#   U ohes teees:
#   Bhe tht  lowe tord th;e :ond 'a?v ,o limt
# ----
# iter 6700, loss: 21.381319
# ----
#  eu'ot, cherspwams dn'- ilast bon
#   Te thi  to ee'an e ser ma mime,
#    beus tin ail casesvenom, Perfip: che chay  eze 'he, und shoramewemi hr
#   WaTtynst sevw okese,
#   Ard thare alt in thets of teaatrea
# ----
# iter 6800, loss: 21.277382
# ----
#  fea hage,
#   Bhe whe shou do g,ory aed:m thy thiuepongld shy  t ir,in  hont ra,
#   Ph-uthoue cpseresowpalo atsmasy ss fly ton th ulnew tiest anlus  eavel
#   g  -o the saletuol ihed rnir wesn
#   Thee bea
#
# ----
# iter 6900, loss: 21.165720
# ----
#  chaw,el sald th-eet,w there.
#  wAx workiweress articy le fiy thanowall'stone aece rond wete thmahfllfitr .- lodd 'hasle tea:unlelaed't
#   I w t  fo t  woue  ringt aek tpaute sngef
# e d the ous  uyes be f
# ----
# iter 7000, loss: 21.140557
# ----
#  sse  Ame tr th pait tucreyss bey peath,t,
#   In  if s  ffutd wonD  sicgdt?watr'h medusiug  atid lorwisoreeet whr dts gee:
#   Tice the du?
#   Whtutoekst why bof n3v ni nte'e ,
#   Fit  aaad roaf tiee,
#
# W d
# ----
# iter 7100, loss: 21.173612
# ----
#   netrocwednng an thout ale,
#   Whrflo?  bo see :
#   A d cheldese
#     ou  os ee thit fist the thore mike  wnot Thiss houeo,
#   Thy thes -iile  hoes ste,e  oPr wings th uhinewiil  nr tord withir  if hrr th
# ----
# iter 7200, loss: 21.165577
# ----
#   slmale dan teles tnouseid s
#   B o :he ti te in re them sores oLstme eas ?e d
#     o qs ouihe nond dsvenenrand bnel s mos  ine cthir,  hind1r derind neas
#    oDi t al mand rhellbssnemes
#   d witn thonoss
# ----
# iter 7300, loss: 21.124710
# ----
#   be fonlttoon len,
#   S6ad wertir' thcn thim neepsemeu: vis dir-n's dhe' tounto fooe'dindebwuswtr
#   7he  hin thy gotehiugd
#
#   M  t     an c tsd the filg mhe lose,
#   Se thopehrrlownor ba timemu nalysstf
# ----
# iter 7400, loss: 21.060096
# ----
#  oamaee nhed fhy olg tho lrty stty dushinged si wey the Toei wutlem on ghtu wim ?
#   O  Ble thav dilr me foor,
#   e ohuse plouu,r wTaltiury siif thinl  in ghansoin?
#   I eWii; th  f fon,  fe fhot gatile t
# ----
# iter 7500, loss: 20.991899
# ----
#  sind wirg,
#   Fhrts  rrd th
# i  sou Tse ing th houldist'ot  woru.
#
#   sh ti  tio walmlyy wiy soelDis'sWsYethlv tuy,
#   Thsist aaht lojp?eve h':'  The gahou popterespidllo
#   F Mre the namin Hetheb trevpan
# ----
# iter 7600, loss: 20.866133
# ----
#  is  oas lis les th'its sind,
#   The tor thy ftoll'st whane,
#   S Bhe dresi bhlimeie thtufthaeh soee 'ir goced,e st se fou weta'irs then the thotwaome fot ceisssllivets dee wist irlLed,
#   That be bun erw
# ----
# iter 7700, loss: 20.827688
# ----
#  thy resdu dwond wiug tidespuavcntfoin bese?j,
#   Wh lithou thouli,t'
#   t thiw wrery melAkhvnj haard,
#   Thetndllest  armtsloeov,
# e   aau lammare dresywoTopene caoptfoutouey
#   Ni, 2soufbettd lousey torg
# ----
# iter 7800, loss: 20.902384
# ----
#  Twltmatd be hacins srndds.im ohiness beriu,
#   BiW seehirg toother ind wgameemlg tinet rudisl ecre.Pinpilg ast bifl
#    oa  aof soek:w bhy wotherc
#
#    re  ous malt m aOl suat loumprath
#    wy milhds thev
# ----
# iter 7900, loss: 20.902558
# ----
#  wsols ptii st tiivd thn pilS'e tharthim sige soiey thy ,oy belerant-hesands ulltos 'hourd risy teosnir th thons aod, foe lThrelr sith ceary gingithiu thauseangm sharend ftarind ssiellis theetsre, tha
# ----
# iter 8000, loss: 20.847306
# ----
#  cuos hey ther arykd cerd werein wata chin nomush tuounbtesgeech yovecingot ih so lrohb dometnageed tice
#
#   U phiule.
#   Ang andyive,
#
# B B:
#   Oy pe f it 'ed,sg no, jo fart,is  ing  tome prenthea,
#   ae
# ----
# iter 8100, loss: 20.827985
# ----
#  s  non lr'erm,d beleut,
#   uaketh
#   Thou tocisy dnthy bearess fov drevee unsts dnati
#   A deduash sei. sis de iee  lath as ath mens rwoeto
#   Oe hiurpiw tit clon sa foulad susht
#   Anpe thy bolf r6e we wa
# ----
# iter 8200, loss: 20.678815
# ----
#  ousist liwursdombdapony famevds?s Wels betusd sore,
#   Th thou  move pOy dom th' snghoul mtalk rreeb sove?  Tp
# W Iucwldsa,h
#   ber shor wt bee wis fh titheld aor asb cinmbhativese,
#   Iuore st bet the ch
# ----
# iter 8300, loss: 20.671176
# ----
#  hmin.
#
#        M6'  Woti ,
#   Anan shon
# '  ume heinvise thy ecmywaot we uhauthathe dogy sserey
#   wang eaf ty Shymuty mnmavengube,
#   Sh uthe slesstrine ling,
#   WfoHlasewart:
#   fovukerhereatings wert ring
# ----
# iter 8400, loss: 20.617255
# ----
#  mrss bm's lifdsery the durit seanlhe dool in teDes sores beohe,
#   Thou nathe gefbese diberatd y iredslap7ome?
#   Wise beatt Pea,
#   Au;, beate wate,
#   W thy Tore t ou  oae n gheic be sBehutig'sulRvety
# ----
# iter 8500, loss: 20.705098
# ----
#  k en th-thonyghthee,
#   Coud eiat, Toan,
#   O  wree  reldhautemun I(gkld wort Dinit dnpoas wes, se lit elg mhin thle crhdniliAg,
#    We magautd sint tiatI  soyd tomLd thaitt we th
#   ouke thauhimlou dwoln
# ----
# iter 8600, loss: 20.642858
# ----
#  t su deroty s-ye:hons dect y srh
#   Toy mothingbedgti, ,in tiremt t ld chail bannswond eirn tro- anlnolc's  ho kout leldr1lls kfre 'nallwemchl are ghy maate r with wstharez
#   Thole lalt yoat,
#   S stct
# ----
# iter 8700, loss: 20.629782
# ----
#  Fin thet
#   1 ti to  rord bail  Sorh'stteantsrat  teec ianel
#   h th wjrrawit led srarld cees riyast thou wleuseaea
#   Prmanot cheddseatbey'd wer the tryet mhsmeyrelenstij shind on hear sill.
#   Wreditht
# ----
# iter 8800, loss: 20.527625
# ----
#   thin  iagt dy mnh
#   Bet ty'i er  sy tel t wiou rnymu tom  allnpris  hou canvet  onllr thy wn thy sonnet,
#   dot  hiueg wewhin5weralf su
# ' gelt penou cingpeig nothe,
#   Th e gereest bisildssould bliud?
#
# ----
# iter 8900, loss: 20.441401
# ----
#    nueasy dnctre t man shtpele iop?w so lfxutbe'ste
#   . (n te bev
# t  osuthin tieu  loMy lhy seaf d: bin'stsliss N
#   L we be riseis freld be u eas pingtond thou hr wild weaus slffolo
#   witg Hvd one onve
# ----
# iter 9000, loss: 20.437154
# ----
#  gearl fey suiigg eove besueleqthee malt thit paptimpgaring
#   s ve t annkian anat veyn tnahingcelevy-Indirmbl-soimery dMaele vingonmepgd hie tseelf?
#   Then teath'ches  rich sten,
#   1aPllaua tht lSee fh
# ----
# iter 9100, loss: 20.465486
# ----
#  e hi?ath
#   ae soho reath os  nid soriggwllid wee d
#     Be whathoumete uhee,
#   6are' mant lrsd thi  ouall s ,
#   Bif lh ansire tuy sroudd, bt uiden thele simd thow beatit  uven sise,  houn withei gee wi
# ----
# iter 9200, loss: 20.455656
# ----
#  ea,
#   a Fiall ahy shavurewpitee,w  Lasi-d Arey fofes helmus lobc rine ssoercrovdlt,g  hry tothot aites sn sothall,s aon:
#    racxkgmes  urehe os e saek pretweer ,
#   Ann tort th wewrsln live ,
#   Hrawf y
# ----
# iter 9300, loss: 20.440115
# ----
#  averingers ano, hae paanne  Testtes nreet
#   Toel
#
#     Ml  f  the  urlln to gop ii f R'he beasd,
#
#   hy  se dfty uis
#   Fod she t  thoe,   Tialt . au,
#   Ahet; hithleveny douln'se m,Bu boredccsld wracy do
# ----
# iter 9400, loss: 20.380085
# ----
#  Wrsala ti
#   F6l yutsin mist,  namlit lest,
#   Bfeld care su rfmotite  ersid  ho,
#   Bingr nele gith,
#   Thent lo bitlo bhmveorowee  no siafrwethakocldgson,ga le  yreap'f ueepoeed are Foute'v sldvety nnes
# ----
# iter 9500, loss: 20.330657
# ----
#  ed baps bnl'ng uof meausuaftuont Ir fiwron  oine toreftif the oneepis fanpgldputl eureest lo  ho blaouredlive he tiy mery,
#   Fh,
#   Thet uomef:  fotho delt wore ahps my be tho orondtbe falawing reearas
# ----
# iter 9600, loss: 20.231916
# ----
#  Isg if tor,  ngean sosle,
#   4n the bwlato hile ope,is anauts lave,
# '  wTic sr winsw th te sind sosl touueestuedi
#    lf?t
#
#   ar ou n sachat  wiu unthe ,on thoustouuhed withy drdier whng th sheu wrale
# ----
# iter 9700, loss: 20.193387
# ----
#  theut eet,
#   B reabe focnos tho gy thy th0n' ioe 'hn , aus edtfe dadk
#   Oh tho
#   elUlepd ind hen for wheid sn olathesgensin; e Gelust on ,am  ateiwgrrmt,
#   os finhtre sry Mristhoundres Thet uinns wink
# ----
# iter 9800, loss: 20.295211
# ----
#   Lerthou:? fant tarendndnge thes tha,
#   sh  eu uelld,
#
#    o  2o  Thgul shancweas tRneeaabe bianeld s  he  ungeseat'y iige therctrt,  ho?  nouel cOv ngMt  ire,
#   0 bn f ous liafeld damle houseste hire:
# ----
# iter 9900, loss: 20.292600
# ----
#  me tpaelebers lols delr
#   A le urest tuse: wo thm memlpmsrdnsat
#   Le tee  bltine p aikedly whyilacorpsofecartir or der sanly Iniwe pefenpvevis bon enm wand aateed mef.
#
#    oe  orcher le tham theverd b
# ----
# iter 10000, loss: 20.245208
# ----
#  to
#   Lixh ro thous,
#
#
#            5  Ar  aao manbf gore th mest thec soune:
#
#   Os loreroth' bevlll ind wrr the the,thnasing ovean,
#   A r nhv
#  ls tho eaaleam'r ne,
#   Se the toaaso tore bouel the thy srg
# ----
# iter 10100, loss: 20.217062
# ----
#   dresetl' seer,
#   WDtutant ahey neaings's,
#   Heou hheybe
#   P afrrlosd thie  refatoud aase ;e tiilv
#   weetuder se?
#
#    tl  hy heach'sw,
#   Nike thou ndeltsaney ghy,
#   Fhre, ure,
#   Thzwen'se wet  fuop de
# ----
# iter 10200, loss: 20.087143
# ----
#   dtoucivedlssanle tire,W erthon  hore held watt oy
# e  iu thy Andad chenm
#   her gfgit found rilinkc mev
#   r aht engleed,
#   Thesneacese-gnthe thbusoiems
#   Thou doresstus  hir totanpores thorlpst'it  so
# ----
# iter 10300, loss: 20.091046
# ----
#  dwsthandbthare iix thee tha tiea tooTseelivdrd ehe,,
#   F thile paith thatheswesthullthaneres wnsweeldumsr uir age forcc-ddimthar thee,,
#    w tha  hise sifen whee  )aot the hon wuglesd avengbr'utd enet
# ----
# iter 10400, loss: 20.056449
# ----
#  rternde ifeht  iok :w  bid tiduth inle trmdithiuhwean thub seale wiigot dose5g thy  miwinlthoub sfsteee be dust tfa3g wtale orle,
#  se bousd tm thor al warty
#   zud thacechenstin ,
#   faee Seatrons dymze
# ----
# iter 10500, loss: 20.148137
# ----
#  l iop,
#  'W N'oanseetons kavt phereser,
#
#    g wh  nod wroc iniube tiee dysd beaust s hes erthe sfete
# t be goe  02avr .
#   th
#   Sn,
#   Thol s
# o   he louat lovecs,id ghaneee,
#   Bebf:
#   Te toe s cecgd coous
# ----
# iter 10600, loss: 20.084342
# ----
#  e th deread thauher
# i gllngt self velus tilnseau Ters firo thiu chomey sithahe ffanc nosonthe tor ti-os somthonmer blld,ti  hene,
#   To the dgelhcwe.
#   A bpising  ir teousey dost or refstolf sinlh dhd,
# ----
# iter 10700, loss: 20.084844
# ----
#   oild cegare thald Tnusr ned th2ty lorfaor soully postraroekerast berod douskato loa tot apaigt th mech bont-.dot arectyos ?n watt budis ,i vouheis sod lox hf rie dove,
#   o deta whet,
#   The  hial?
#   S
# ----
# iter 10800, loss: 20.000966
# ----
#   bes lr tn th the  nout load laay t aust chec ,un th
#   Thou de tand mhes bNsutl dale s soillet  Bot be teeP:l  tof these siml,   ahhe  in io  titu uary muaseas dlheligeutd thin tllvkico an yedscing. j
# ----
# iter 10900, loss: 19.898842
# ----
#    Iar tu le thant thou winb,e  Tielweseekowe tiket, werifr thigf hotenis ou hhiu thing knelemuve,
#   Rod lfwfel vemon:,
#   Fot loqsmelf shwtid fuis)th skelw the ,
#   G:Buwemyo
#   Ferh lemery Yblagd loe  h
# ----
# iter 11000, loss: 19.910385
# ----
#  ongldan,,  or  hin  have heg so fzar be uwe t,aeve,
#   Tho  well wirl; uust cnvwnuld's tle suneta byouepteifqges racd ba gnstl poing  i
#   has levh ne,
#   git wy here,g Fe toakt aarssothon,
#   Taself thy
# ----
# iter 11100, loss: 19.959838
# ----
#  ng aarevorld geputein Ther reed Io  teou ameas ahe theu thatee to than sadenouu ,
#   Thatingtire lin,
#    Pantyesees melf wet y yimes thy susaet ievdap.i le so moi up ine terourlrro heranl thy vorl:
#   9
# ----
# iter 11200, loss: 19.938596
# ----
#  chie thenearvcsndsrond ouslsfsgithe tanjsuslpd my ;r df facly rineilT phy het ous,
#   Sn kon  te fhy deif mawind lantid wont,  ?on helling ii- hoabe'sy phervie the,
#
#   ung dout cuse,e?  haiki;h brbes b
# ----
# iter 11300, loss: 19.923397
# ----
#  hen d ind deme m viry .' fSalithin thy iflTin the gauth sfifty com ty beness thy toonst ovd,e,  he toarler ' thed,
#  w t nvart foegvduy c,?
#   ?l  hot anmeprecousd marI jn nir wacrnsllld,
#   Whe hor beir
# ----
# iter 11400, loss: 19.877593
# ----
#  om fhien woned biith be ing:
#   S of wnmfes eut conee,
#   Bhe welt the tore i ghen,
#     Th th sel. w ritheus rite the sneve:
#    uo  Wniug hhmesbedis  orceed thker faouthof sseelno lavdse thy  nouher fat
# ----
# iter 11500, loss: 19.832537
# ----
#   beeres, fach wisgty stosd dafa?w tho u ain thous eeghy ou-tollere?--uvmmea,
#   Wheqe tot mame
# s Thanewsto meige
#   Oeal
#   h th thplldnst  foul see
#
#    Uh  oog  reaty nowsthiugolt eo  Be ard ende brisl
# ----
# iter 11600, loss: 19.753789
# ----
#  it  onpeit ther oake n Aatu yomatrigd cy the sy thoth waitl hind eswath thee,- myor the ;oddkss heis wytaip fneet onld v'iungou gen thau, bin temind turest the lunate thehe weok, her thlil4 tnit mene
# ----
# iter 11700, loss: 19.719654
# ----
#  hand parhes sotumacuogd
# s Uelfket un therebeanr,
#   Aine apthingbey wey ce5st migd duth,
#    ra6k th  bous beveluddy
# i  waal, ereithevesy beithaoy ;fiwesthetaos th theasmrrgvetlaweto.'  hike mune deea
# d
# ----
# iter 11800, loss: 19.829596
# ----
#  urothis ary port the steae,
#   W thithcn fith be ant  n tho los movo e ghyhe jdytp meat for ciaot ther chuct stily pivbdouef:
#   Hhg live innte se io;  iigy btiogige tiovigs wet
#    oik Wer akf  ines
#   O
# ----
# iter 11900, loss: 19.823016
# ----
#  ronnd louliayclhdsinltho cheesrares wate chy sacfnts ty thej wee whg rov.ass orp,atc wuarer, wiestore -ees mecd,
#   Dereth
#   AlT beataad rospd ise 7eoule the beau,  nanelessesc(dertxmey-easiu sOd cou's
# ----
# iter 12000, loss: 19.794976
# ----
#  eld thenjdsppust  houngmes
#  wa fesg bhes Ie (hy badet ping'  rand  ou y ghiut:
#   9y
# i  ayc tho y weag ,tm simes  faren bhatindiresw nerish thively R ssd
#
#     Te  onetf es irvi cr bf, ar fswewr un bes
# ----
# iter 12100, loss: 19.750113
# ----
#  stceledeld wing
# h Asthe srespiRen the iesthe,
#   Sheerint anofbe.
#
#
#      r  on  hin linwi,t mNsdns, whye,
#   Dy self Fre dovivt paiimuskall she, an fago sy pinese
#   woin's the  ho tho be:utn thi haley:
# ----
# iter 12200, loss: 19.635411
# ----
#  sthet hlthynsiuW lithm geevengess sftLy se  id the botivelo leqseas the lasttyos yemath wheel' simg th thtusurd onlesAlf Drruriss nnwore theninlt and afinhd tilf .r ghareerwfuto? d lalt
#   Om anlpssr,
# ----
# iter 12300, loss: 19.655115
# ----
#   ugeanden-asase whors plafcy'geanle th?e Th nefes the noat nin whor  one,
#   Sede sof dWns'eery thanl aMd's anlesiil thould sichlast ihyf wotecs bamyit wond ihem silkapnpeightrey tha8le-patine dag rey
# ----
# iter 12400, loss: 19.620810
# ----
#  nt uart,
#   Fore dros,  nailrt ming,
#   Oeliss A fasr fftile,
#   Thro bes gou lis eres r.o
#    ianke howeded'dw wemd th cidlthal''rong onvoul'e sis in thi l se,
#   2is thy rast be wioub muredouuake dostee
#
# ----
# iter 12500, loss: 19.709722
# ----
#  :
#   Why soy dard thae,
#   Ahd thaoe sMmalt Tfem thounshaw,
#   Uot is busthous rnthingris ndlekuso whimtky sun,
#   Tho  Bivent, beacning,  aglthas iokfthiurthas sfroft sbevisd?
#   Arbe conid hhy Aur mekute
# ----
# iter 12600, loss: 19.636886
# ----
#
#     a  Fo k ves thor breain's paPdl
#   The oundtred,
#   The lolDirls zy 1eants lf ry berke,'ln tisuthy goasgongleehesundti l?an than baaut :e sI love,
#   Wo har,
#   T an thee woe snton sidght anlek
#
# ----
# iter 12700, loss: 19.615546
# ----
#  lote qn mhy  haanen ld Mree taFen finth chower yu:e,
#
#     a   t  r  he  to the wttd mie,
#   Dech sheceraf op frrov dveenss lfder
#    re cher oeefnices ahewhaur d te b,e 's tice wRet  hoihe hereen thou t
# ----
# iter 12800, loss: 19.586113
# ----
#  -   ok  le whthis thas se fre and sseluenserlvesthe  ass lops st thy stg anend lome for not preow mlase BitkPtte wy,
#   Thanyus thet lnous mave?m  alg biftlt sed the ceenhbe lher shen wote wrouu hongde
# ----
# iter 12900, loss: 19.450267
# ----
#  els the thane's thoue  ope nspndertang,
#   Th th e:
#   0 muld sucess mntho?  aoe heeeesusqe soed uis me.
#
#   Mhed theneee igle
#   Mo?he  batlap  ltedewiengetutu 6 tho  hoid eothe  bee,
#   Sy neote cind'ct
# ----
# iter 13000, loss: 19.475682
# ----
#  s thy swrim hin cttite  way worhineps -eneee
#   R Maigk
#     hy  oe bemerbeauteath whor Lous lo, the dere s ancbe time toc laonge toab rihes capds fnrle does worte,
#
#    u  o  n  s pig oue's tid-yoce,
#
# ----
# iter 13100, loss: 19.522610
# ----
#   wat iwtousverit's xnture  ing, watu fob dhere thu h rupedis hrws thee toof dmesy bothy sosnst led tSouselrigh roue douthe,
#   Tha ty's  olafs l2net bisese srmes lr ho leo:
#
#    nr  gfere tar ss faethe
# ----
# iter 13200, loss: 19.552158
# ----
#  5d shre,
#   Srot putew rild tuave dave?
#   Oi twaty whrtgis  laeet
#   Mhh lert mey todev,
#   Bee toling las
#    nt  bale wonmothew diwelt hig thase ind oyld bre th'r loy'rri gotes weify dres'wele bery houg
# ----
# iter 13300, loss: 19.504434
# ----
#  n the were,
#   hos,
#   Nartobeprabda
#   Lhy restera-d mant be ysuiy or rhy santouel cBnthestetu le dim rhers if hey thabeahe
#   C Thes  tiresyin  hi;e nruth tit womndseves ,
#   Lr th ge tam thil woracd lin
# ----
# iter 13400, loss: 19.491016
# ----
#   3
#   kis  oraney beade.ied witl tio lh eoit theus  and ind thyel,
#   Thenlfinkaur mlmeddes in5-eathy pnel:
#   Whk mos  hoc art fhibe so kifg sirer  f the can, hel beeWtytt ead,
#   Fath thee  ase the tore
# ----
# iter 13500, loss: 19.401557
# ----
#
# d Thre tin theedertins  ry hand,
#   Rut where butere.e SOessns melh verust rine souThe auss she syivess wite tu, lesserd uuc ios b, Thaurnoat unea,'t Ie w,v
#    oT  aot ;rsuin weith memcty condlese,y r
# ----
# iter 13600, loss: 19.369453
# ----
#
#     T  k  e  ge  uin whep corbeatote s mesthis thean fawcabe, tur'ne  arSBuyy sonhlr thy cortet eo chiy thetialt aaqre more toulsself sith.o w?rhn weet  ho sy Thibegeon,
#   Thot  aie  hopshef wim nere
# ----
# iter 13700, loss: 19.289755
# ----
#  bealp bey danttu  oe anones fiild be thy sue ie to toeon
# 'e  ho mant ben to fatoloee piches  apt  ce cate,
#   Nhe sw dlind wonlt sine,
#   Thy lFatty wary sue,   Buce,
#
#    Toe  wonty stithiog torem bestu
# ----
# iter 13800, loss: 19.438220
# ----
#     o  px lg dor whubestst wety be thes sson thar Aire
#   Dit ofstild thy Iwegd when act ben,
#   Oir wopnous manth
#   NithlFstee wy peumd naS ne d' )ush
# w  tr blw tho doly sedere totume
#
#
#    0  m v
# ----
# iter 13900, loss: 19.425656
# ----
#  lpunit t cAud,it beae,
#   N en thid wemf cor srebt goam enothed secrime suseft insthane foule tiissTost that thound
#   , jL thy brisg ovece,
#   Brind  hay thouhd txaor sunlkbuse,vant in thahe aote plithi
# ----
# iter 14000, loss: 19.400441
# ----
#   ao  Iw wisteat be sous Ahd diptic,  hor decu whob d indoon fretl anand dand thany hd cavfurlg cind thy crees thofeeop tio::
#
#                     M   AN  foue pinns apy h logesp
#   S bet thovas ohghete
# ----
# iter 14100, loss: 19.338190
# ----
#   oas iflehy goutfTie,
#   Addos loch foud lit th ct oo don toawith AAell dost Busegt
#
#   U l the  Mel mn the toy;
#   Fais gist andest ongews ?e f ee?t e  Clld's byy
#
#    hon thei nntaid thre uras th's :
#
# ----
# iter 14200, loss: 19.280637
# ----
#   be feiburebuge chdithr wegowes ouremavees ousegte timt tent ret mlth be ety-sulf,
#   Dit  uith cuerutve,
#   Leed soutee,
#   M Leige tho
#   T se  fe thi hos lrveilggl,
#   F thou lrls les ed aneeeg westrer
# ----
# iter 14300, loss: 19.264295
# ----
#  hot sacrld whwuroelrive-othaut laezy-sopwirs ill:t homsloy ty wimt ch olestedy'couU rraly size tooe,
#   Afonkeee -rereitgheleam,
#
#    Po be fond thy weys:y se..
#
#    t  in  hat the ghguimen,e lBttnlcosis
# ----
# iter 14400, loss: 19.271847
# ----
#  rd on thousthot beaity'e  why ;eelf?
#   Thot wot  ar cindowersene:o,  worihor para,t  nop roulh  ooy ,,  rle-crwis l tind the  Bveyy sive,
#   Aupee,
#   To t biatity derind on biner sin5nMhing ehe ld ho m
# ----
# iter 14500, loss: 19.317055
# ----
#  id th le less?n;R thinb arere?us thy desualy  hom wrin? sirt,
#    gro
#   n m r tit selasg rasheno sh fhety-y mathe7
#   Thke fale bowbtsisess ip?ing makh soleld,
#  wDot gonre to,: sSe thy hy wets lee drbau
# ----
# iter 14600, loss: 19.285568
# ----
#  o anesitd collv
#   Bollos s oss want alleserse?
#   )he s son teoue wess beneene
#   tn1t Ials mnes thy wild tilpth
#   5
#   w th the thivele iny for,ch weecredsere hon thap:
#   Deaubsuseis nell thy runen
#
#
# ----
# iter 14700, loss: 19.260621
# ----
#  eds te c rythat  hile ponld the the ite fare,
#   U pot so dallbn ongere,
#   NoWeom meth,
#   Thou mote aaein bonn,
#     ok  epchest ou tolt the  thea prmen ihie teleny whed hidib, angtess ang if rel
#   h bh
# ----
# iter 14800, loss: 19.237737
# ----
#    tele poo easr he to feesy skeke .o sw thr the ise ss dfon threed4simg too  er met ir wend-sothes alpsiye teoe trede siee,
#
#    e   o  g  to mast wnote uen thitk
#
#    o  th  nethiu seaprede:
#   Ohe cost
# ----
# iter 14900, loss: 19.103806
# ----
#  heuswint maallss if gi,e walt ereHt winlair eor beraty ch thee
#  YS aft cunde tay cBlast ther inggeevth:e d ins land ow et ear's,
#   arr mos en an  whe, br nor ine deiut-rwsewp,
#   IoTheveand lhapouess t
# ----
# iter 15000, loss: 19.128962
# ----
#  t inene eoveruqr se fhe , ae ragrsm shi(ingt too h. mparcbe,e por men
#   Ao nol: ning
#   Fith e8 ang-hspir th ld'at,
#  ?
#     y  l'  y wcy wiut ond th uhy barustoy Seacvuromus afe beartke qf thdes
#  me dim
# ----
# iter 15100, loss: 19.191736
# ----
#   nf lleai  hat masW lctund ing.w wo lo
#   Yle wirt elatsy'meind wiat cunbealc dose.
#
#
#       c   b aut di cy he?u heuswert wela-ves an,
#   Thes bemathis tomu gsciald cho
#   ou;:
#
#   Thet pnttaip srmmer ta
# ----
# iter 15200, loss: 19.221884
# ----
#  o eingd lothass meqreint inine's :u ve fithe sordcteymeye'sorwptild oneaic,
#   W the .o he d
#   a uilo bre hiahe thaniteas eame tor arisw we tiit row tld sreant,
# e Nonveast in shath  ceco,
#   Ih therdige
# ----
# iter 15300, loss: 19.161582
# ----
#  ronresene
#   ho lle toy beangessed puy birderu'l,
#   Acd woo ;S'at tuule,
#    west wot 'ant the th hsoow sabe fnitith:
#   Bt  ung if tho  rivthau.
#   Wion -hecerus snd houth the dede or the withes wrqkons
# ----
# iter 15400, loss: 19.163760
# ----
#  thy anrache wored .
#   Andebutinks ang ap:ege tho nage lone,
#   Thhiloef phithchelc
#   Th's befth by ald th teoes thou thire hou thale faS s lagli hod goat,
#   Bhe toant tontoola bst tioan ueld bued on  h
# ----
# iter 15500, loss: 19.076060
# ----
#  va gaTey'y soeed tind b'aty dillo trso enitt to  yotly dise inxillthy worl's leap aste st pnen thone,
#   Fhe  ar the  fithros thybgisless Most lle
#   Thave srays ffiel ineriaN teat  hsill,
#   Than thoure
# ----
# iter 15600, loss: 19.041122
# ----
#  n thesd foruot  ourer
#   B hew wind,in f ee dor macoedseefers?
#   2 n  ne he bey bracpyene
#   Took thath uuoobid suthenlWsbe me thin thaut yd chzeuthe'ssthe  apmimgeelabe jween whame ro thousgland wid do
# ----
# iter 15700, loss: 18.981216
# ----
#  pe:r foth unacuse.
#   Theu st ridg urosurus easthebeast bou dino g the whoul jott aar wectly soengakess khy eldtheeeys wies lf-the cptitkor findssthung'skely thy stpoicssthov theeidks meqgen'thiog lin
# ----
# iter 15800, loss: 19.119721
# ----
#
#   he co:e th
#   Tha tne tiog tirlo sresd mapt hings ning ul fGrl; she thy shektretr,
#
#   o    T9 t  or lowity woll,
#   Whos uacp oourrsed rsr
#   Leou ho d gin gtire mesr ahe d neo best:
#   or  in tor sol
# ----
# iter 15900, loss: 19.085698
# ----
#  ty seau con,
#   h mutheg:
#   WhShile withy sefre.:
#   O   cle mi-hrcistt ore thio base bhere hinens inggatd'st the thas ifor aou ritrt ee d's wolfou, w at thH culley wirlgth thauimere thed the,
#  e  mel
#
# ----
# iter 16000, loss: 19.078608
# ----
#     os gon tpauere,
#   Theu fyea ty tl ovield'se foar:
#  F oB.,  wott sin:keng arou
#   d lild rerivdnit w all,
#   Myjll:
#     s
#   I  f st be te ,
#   Sy ges my hie fharsre lieht,
#   Who then wemjef time mand,
#
# ----
# iter 16100, loss: 19.022146
# ----
#   g are,
#   Butuol wawe the wistso, he tby,
#   Ii Himkt loon  faiy crous aet ute,eange
#   steucn tie s thi los.,
#
#     f  u I  wing welre ovec
#   P auris  hot nelov duthe  uaikin shef wiellover-gorcend y s
# ----
# iter 16200, loss: 18.954762
# ----
#  hino seafs 'aterey me  if sr seou:e thires sckeero'e
#   Bim fowf ter in;  he condirW the les''f uod leaatyDe,
#
#    We  on te timeruge fiilg,
#   Thee esttat apd anlesprlsthave wee:
#   Soegfagh atonend
#   Th
# ----
# iter 16300, loss: 18.940423
# ----
#  me
#   Thett ave tocan6engestast beoIt nos dfle berrty shetlrrisg the eoves :De d, f.
#   No thy s ladmeareek hingelf prf tingt raty yovere,
#   Amd h yvestmeesine,
#   That owd thle, ire thins dos srcv hhiul
# ----
# iter 16400, loss: 18.982782
# ----
#  meens, epy llwaif they choueit theus an tene.e's the  dachime wore threes thot oute n weThary,
#   Sze toy melald,
#   An nkith tardyss ling,
#   Da
#   Sl mosuues sngelf thy  Tarer beapt weou dothap, or lSe
#
# ----
# iter 16500, loss: 19.006556
# ----
#  swprithertheresy.
#   Toy tease siat'ind Lorl maid wyod wnithe toy sing
#   Fy ?
#   6 I  fotinl
#  n tho loske (etd by sindsear'n thing sa,t thererifs ye,W Whojusling tole aiwe:
#   ge-c f thy lhycssthise pof
# ----
# iter 16600, loss: 18.972394
# ----
#  omarl gipdted sagld fouk fne for chensty thar sheuind,
#   Lumison,
#    are c miseme
#   Se oii, thoustonensts (vebe,
#   A durirs lweot ar eea:
#   Theteserey?
#   T ou leru wor intheu aow grlaye3heg arsuourene
# ----
# iter 16700, loss: 18.943382
# ----
#   my d,y we?l bBusif,
#   huress oreapts wheas esthin sov ry houle
#   B, ind si wiat thea fomhity iutt on witd thy loob theu
# y  Doy-,
#    ar  ius they thaber thithass th tho hary brien woith bnysut  ind:
#
# ----
# iter 16800, loss: 18.924239
# ----
#  e thou when au'
#   U qe dlosers witr ef thous,
#   Thot anl est  nouer fLart  an  hask
#   Miie,
#
#   h?
#   or the out  iuh.
#   The inv en e' thou  sith ta les lls daccins hbresuss worl th th ce;ad Singr  hyal
# ----
# iter 16900, loss: 18.817161
# ----
#  ine hoen laft the  ant wont hovereed hos Beiuls,
#   T witbensh b tunt thpferlv-g thon:
#   Fir  iove woeast pist ind rart or s eet  uoinl:veaf wibl'is noseat fiwhele widee,
#   Ohe tian the stobe serB thpr
# ----
# iter 17000, loss: 18.826130
# ----
#   beanoy Itcimanb aug,
#   Ih tise wy le's yng ronn-unefaty Ous thy shaflond boeu:
#   Bys th calleef tha  usalld ptitd-cDerthry sund teou dordssra
#   Ore thyeese
#   That:
#   W the balle
#   Tar fpert ce lpthy
# ----
# iter 17100, loss: 18.898130
# ----
#  sg stale,
#   Drsd thou thy csplut be, mngle,
#    aU  fof horidssusoy doee,
# a   ou fat ind snall s aoc  hing isc?f,
#   Ir  haty wurey,
#   The tefuth's .id thou thine do fpinjg me,y madles oOd wiouc ary bid
# ----
# iter 17200, loss: 18.935980
# ----
#  r,
#   Sely beat woithlle,
#   Than phanint.ol  iar,
#   Whan:e  he iopsosc newuterise ghea tothareqOr ass
# w thr  mior ?he aposth ul thiy, one dide:
#   Wy polg tod sfsaamds laviresy feafthe rreatreire enncte
# ----
# iter 17300, loss: 18.864625
# ----
#  injthan tomusty se lhandef hidrcines
#
#     T  te k
#   Ake theanom thmwiors ur,
#   B thme wisc treen sb badpontor sa:be.
#   Tnate das, hin thanl,
#   Thes serdrud thy nosbamedstste's bawery,
#   Thanelefiis,
#
# ----
# iter 17400, loss: 18.865812
# ----
#
#   st  iT thi?  Beethon ghon, an thend lo for groming thing naty,
#   Thous.l
#   Shen hithees liagh
#   Tho  ar dois'thinreex weth weve wath'ss ingeire ingthou alk dlswstld go baed whet ton irgelirgss ahe
# ----
# iter 17500, loss: 18.780103
# ----
#  st aut,
#   Lhou potory
#   nos sh dele dpdasus dusselary,
#    sile tor veming uige:d  eve nokuo feals ise,
#   Thot derutd westhy zuacTied,
#   A
# t The 'I  Te leletorpsishes ?f thy coffor thy btatg,
#   Ant oer
# ----
# iter 17600, loss: 18.771462
# ----
#  oy wist dis thebe sBelitheh seliv,
#     ou loth usttaky Svetee ,
#   M rhing ar  han wolive,
#   Than  aarier  fiit werus fer bithe feebecfesags ave matr ise
# d woel sh thaos oe aoyestaniall winkt mort wil
# ----
# iter 17700, loss: 18.718151
# ----
#  l
#   Ho ild dir ch dolo girelorr'
#   m au9'd,
#   Then mesute
#   Aoshealess beothruntir soeld  lov)s rrels simnt
#    whit thibe frile  fres winp thes thit ?o  ond rire tey s acr, :n r thowheg thy thou whome
# ----
# iter 17800, loss: 18.852389
# ----
#   cey wot llveny Lo Whes-bashese thy stad weat ss lnst fnay Thiue tavis mest tupei6's deve ther plapsiydqesee eish thit thoun ls 'lp lingr,the  aot  ir  towess wton why the kosh tist leas ber it rirm h
# ----
# iter 17900, loss: 18.804168
# ----
#   binutele hemeves ao gener.
#  ?F wlle theust sosh svestis thy?
#   Ant tham. se thy woruveougusrant bmen tulumhicg,im sn fimh  her,
#   Tore sfaike hondireel,
#   TharrfsTstr weos thy erowkeor simes tonpbif
# ----
# iter 18000, loss: 18.791936
# ----
#    or
# h s wesusd this sutfing  amothll butun 're wellss thellos shes,  orint ing,
#   Tayos wnth' eot  not Lrwtt arebe s' be t' lowcrowuinoweel,
#   B,g gf ad thin nestfytous sind enin  uall chessate t' u
# ----
# iter 18100, loss: 18.732099
# ----
#  se:
#   Lemous an mith  lids,
#
#    o   i   a t y fothet'Tis nllse,
#
#
#     W  te  ous thrisspbacuusthy dit to  wons pisentee thasPndonl thce,
#   Ned tals foy peurey.
#   Bututh ens lepvind ave?
#
#   Thealle,
#
# ----
# iter 18200, loss: 18.662952
# ----
#  suss tiee,
#   Mon kifhe lfatry illcgong,  ;ail doturling st ty thy gowhel anll bare te
#   Lhea, siges
#  aM andone ffaiggg thy toot round,
#   B t6ouss mury meranroldhB
#   Thr lf rnvheseal's lfgbe,
#   Lhovyap
# ----
# iter 18300, loss: 18.670176
# ----
#  rohetylonk,
# a 3 heneR,
#   Thedereous grmthy worbd wxam do th mese,
#   h 5uchat theu, wedhiny blefTass whot  uols heregosreef-rtsat at ond,
#
#    o   h  er st eneeustins  ored doeghy dall thous les rloibes
# ----
# iter 18400, loss: 18.724756
# ----
#  o
#   The wokle,e  Meer
#
#    o  oo  on wes lleme d,y dsed thoi belur ciw,
#   Sareile tnrhewfoun indthy snef iu wiot:e tomd   sin thyh
#  roe ghee wremesy sives  foureendust snreny a5t ilg whyemung mThit the
# ----
# iter 18500, loss: 18.750712
# ----
#  gles 0hic leleve Bon sosstftend wh e macd vAathit bowe tiist lank so thous ratt bendn',  naty logf forsnge, ongtsrelssey
#
#     o  at
#   Ah mewety's ben'my Hochinstavile steBl wenis self the suld the sh
# ----
# iter 18600, loss: 18.709955
# ----
#    Dyk,
#   B lnd lo a not
#   jelBst epcend esty de the dilo peneat phat ahan'ss tn thy boaneragh'r whou thy cost,
#   The idenlas'rh thale font sall thes ceres rwett bo nnitg thD lngeogd sn that ongler, hi
# ----
# iter 18700, loss: 18.675801
# ----
#  nee tuo bule treet ove ty n tithou ptor  aid chand th thy -uif the horeeound,
#   Dwacts wh ty thy grahe bou,e -oures runhy srasf hutunl's  eive t miny ane  le mowthr air,
#   Sharese med ie thy thy abe p
# ----
# iter 18800, loss: 18.660623
# ----
#  vens han thlamer in  ho chscperdath'p,
#   Than ohd ,e m grie tiae baace poe,
#   Sathat tuon novenu's lAve is elf ele's piid sueasweee
#
#   Tis te th thtu
#   Aor muth hereds nrej's snges mimf faady 8onnktmo
# ----
# iter 18900, loss: 18.549655
# ----
#  rtine useast ane white lhes ton tind,
#   Thatisl ipliud the thee thou thou Iaith tole ild stpintrew,
#   Lleveav'fw thou Thin mstht bathee?om fapieg ehess fove thir thoup werb bealt gee sy mohe,
#
#
#     C
# ----
# iter 19000, loss: 18.560343
# ----
#   eof d piins thingecs le-Bipga th orope t rha dom whit celmiks wgof fhy nre uon't'sebrackithrr fain mefuter go hMty haut.
#   Seytr eou sywerl's aWeatcoush:
#   Fo  peat hos llNmthe thatenf ulpsebs re,
#
# ----
# iter 19100, loss: 18.640733
# ----
#    on tea ho  ortele chy e,w tn thail s les ingefhenus  rofo s fnmthws wote navemhes ky Poing,
#   Thatr:
#   Liks alatt efsen  ham sotfes thean sssllhr einherLelt ais where ant sesre thou  ande corks arot
# ----
# iter 19200, loss: 18.674764
# ----
#  ov, wot caotaru, ofknds move,
#   Ant theo thautthth uldsrhe widat oust:
#   u U
#   Tuat, sndoge toof trene wore,
#   Why lFetit berith,
#   Resl movent rond noutrrist lla bis .ro  art bl uetu thic thper ans m
# ----
# iter 19300, loss: 18.605345
# ----
#  rdea.'s deve angeiverte eay,
#   Shere,
# o  wove tom toon eaaud nh eheren:
#   Tut o) tor
#   w thy sus lo dlnsted'stwith ng lken,
#   Lworeint n eaot, e se sy they totiredr daglBud oin thin wedlim s:
#    har w
# ----
# iter 19400, loss: 18.610930
# ----
#  weane the y salsy won thougatsing thy -besting,
#   Sher Lant eS
#   def kxvtoall wseked ety dacty dedais bichwerpmoun the belang when tracenou gres
#   When
#  eT teailo wirt ,e  piitho
# n fitl binder,
#   That
# ----
# iter 19500, loss: 18.523868
# ----
#  ist,
#   Nfonlwera,,  klekl
#    thiter dith?o west wumt thy meivest withes
#
#    o   f th thou sxifr,elow giled wand whand hisgre'
#   O the d med
#   Tlathy slabgrold sot reu bey thy sereIw,
#   Whe eovec  aqf
# ----
# iter 19600, loss: 18.512966
# ----
#  ngleswere sidd hor'se gomdth us trwn
#   Winelomur ing-ulauty waut outhaud dhane,iang ssey
#   4ibktone,-andage
#   he tpir thoue try soffanh's wast to dft auw
# s Lin kimterevidd want eou ls gr mly whar, pai
# ----
# iter 19700, loss: 18.476582
# ----
#  ow-ungerere wit dol
#   O i
#   gea dosm lxart oud ty upes--amtit wild wepthy sudhey prast,
#   u dllegertsey doot ,e bCtand when-:r mokelisggsorear womne  ne tho epyipd:is tho comani gner
# t z  hiek preiso
# ----
# iter 19800, loss: 18.597092
# ----
#   wisuce ny:
#    he thatu owiml th tiel
#  f hTnnsimilh,
#   Who sor erreouudle?v fe7
#
#    Th   Th tho paron sigrtt ofoe, woe, toce love:
#   P th thy poldear whyr tast the,
#   Tho  Bat dese donge
#   Fhin  hite
# ----
# iter 19900, loss: 18.536692
# ----
#  d bnaty ghart en ant ceees bitast bair:
#   be hiwht in thmu dochor ant hor dolber tharef an, ofe's efseeor theke te
# w  ho salt yeluen,
#    ins cweru meruto hnpnsty usead,
#   Ros worlue tean thensrllTy b
# ----
# iter 20000, loss: 18.539432
# ----
#  y werim thenke,
#
#   Wver thy  ives theer'dan het,
#    hw er bu shir to thoet te,
#   And  an3in se try surctnqied,
#
#   Tho  soifer tibl,
# d B nowog  gy feine,
#   Thotlleiwro eants wo f mis  foce woele,
#   T
# ----
# iter 20100, loss: 18.480606
# ----
#  Th or hou beauty's movend scou,  nouhlsm beantexuss lha los sthyl
#  nCth
# u P,as okemite the anges:
#   Bes when the tiso thoureest shou dW if ard'scn gimde',
#   thive bo lo cored mast dy dot move ghor, ba
# ----
# iter 20200, loss: 18.421159
# ----
#   oveut 'u lele-wisge seet:
#   S thit  he hishidstan ds her pous woggor ous cagld sirhe fingpnes that eever, gon le cemshd woan laveris windeid sichere sobe pous gosudelf dy Beeauuy cinot and,id thy dge
# ----
# iter 20300, loss: 18.420844
# ----
#  d wirl omeatay damc mo  lo hir  oratip nothtareew and hath conghigy se foza wield-wals Lyrme ceasbeh
# g  no thoufly Singpifogt sous,,
#   On thy tombe,
#   ooTh,
#   har the ifesing:
#   Sonlaf iith weasl wofp
# ----
# iter 20400, loss: 18.489591
# ----
#  h red thoueuwig whitllon the ,o hol theu foai bor they ryainele iry suen;t conqtedu reaun braim seim' thyikisg owe tinys thou ane echise wait wiiat  nopery,
#   Wile dhor datus sude,
#    aaccruse undoth.
# ----
# iter 20500, loss: 18.508147
# ----
#  nes d:da
#   s mepy bead,
#   Trou honeercan;
#   Whoe dovid sin buend dhouu:
#   B wie5:
#   Ant eafBupfose feivess ghe thone fre,  fTede:
#   WhStiy tern ees,
#   Thou fovehig thy bevetust ense?
#   The indterdssth
# ----
# iter 20600, loss: 18.470879
# ----
#    h  ho  sy thena,r mhed ial een te umish loss,il Try bellvent
#
#
#   N d  h cund
#
#    h  hl  in thy suthity bf mndp fuk,'- ouSty beaw:y M hy chaclld,  se shes artsaif ledhele,d Ih de d
# ----
# iter 20700, loss: 18.445396
# ----
#  o fry ve's mevery:
#   In:
#   And hhesilt what thouldicg thy manp, th bit thuf wink, th lreact bs aty taa thap, sher aee trere sorld tiae un's if soluke lf ild hhad stare  ouch d'ut want bif th aner sle
# ----
# iter 20800, loss: 18.424762
# ----
#  ersd kita u.e fWalcislwnthr fewsan's Al;
#   Bllfthr ar avelf by mreu rre the telago lRvear- silanor thin thou lSsmy chast mar wot pnouel2-ergvyes thC-elous's rove nToelengst thar oh theeeUut,
#    nold w
# ----
# iter 20900, loss: 18.328635
# ----
#  govish gsemere the leadty ce In tr nge
# t  foee,
#   Anamimerery,
#   Bll in tho collsirot  Soue.
#
#
#      n ch wfatlo ser thy sogthas, when breed'serwentnlonj,
#   Siven thou thy colfes elit tuouall thy thau
# ----
# iter 21000, loss: 18.314611
# ----
#  srag the thed shamise toouren.
#
#   ha  wore if es.
#
#    er Wha6e sileronb higlbedid Woif mesuen;, ao be poDist lovf,
#   Bn tha t melf seacer irartoeN tond iCvilC ofpmigrongsyin the baace fhe ftel My shy
# ----
# iter 21100, loss: 18.413264
# ----
#  lles bray nosldony shes xake,
#   I  tir the thy pLeaberi6d ating sewLty mothof edkeny sgos toarest?
#    he lovest srouey glegIty and mamind,
#   S8
#   Tho hopd thy beattat ao eLarg wan,
#     oi s lf tics ho
# ----
# iter 21200, loss: 18.423352
# ----
#  d we coouthon fed fari:s  onthin thou lavd tout ygcalnoted chid, mao9ks ty t rfans thou eath woes:
#
#    f  fase datteut ere,
#
#    p   u  h mereeand nuty  ae iFlr murIbet ous ar,
#   Sed that aelecttho bl
# ----
# iter 21300, loss: 18.374601
# ----
#  tistr finhs aurl
#   Sist Beay, 'hi deelive?
#   That 'e thy doln thy Anriele thei:
#   Sx fe l erod theunored wsomer sede
# t Thot ore ge.,
#     o  us  ray whiteratapmierd sakmss artimeresb'sand:
#   The worthe
# ----
# iter 21400, loss: 18.387595
# ----
#  d's fw se me thantstle whes ,o neae be areser 'ith
#   Whep oy tny maymf taussere ceaesudine danla
#   ail eovant rtath beealj?p hanl ,
#   S at allabear eanke Wownsn
#   Lond onit rijgrmeur vis she, thouserw
# ----
# iter 21500, loss: 18.287481
# ----
#  :.
#   e  ousl ther eot wontw,  som ley theugustealnds
#
#     T  he  neeas ehe nssothl s adkid seafing aeing hy woht arld mo(t,
#   tuvin  yree,
#   Ailet wredd ane qriou levyde'to dases -orath thes fr seoves
# ----
# iter 21600, loss: 18.305725
# ----
#  at stgelbigest dy sumje.:
#
#   w  h  ho  feot muncssse fheuet aus la-,
#   F th ne ghmus thnale nid,
#   B t then dowhen's wopein berith'r srcait bearise sy ftice,
#   Shan:
#   The lbertse nomere,
#   Then thaut
# ----
# iter 21700, loss: 18.272102
# ----
#  s wiagure ty'es snduse lesey sTcef bed shee are thy nty luoqr's whine houre saed tiot thin thqulastinghar aher thy weadebe ehe,
#   Bee qnstewinl sires werfacr ust beury cind houcelf why ysy tonlowb:  S
# ----
# iter 21800, loss: 18.371758
# ----
#   rseed yusthibe ing thy porf ile,
#   And Iutheus wheneeas mest t
#   u dunlf gom thin whare oulantte noy phim poreaf be ary,
#   Aus,
#   Thou grtm whee braute ton onf wiel he, irer,
#   ThLeickald wert ou. fh
# ----
# iter 21900, loss: 18.313052
# ----
#  e to uhame:
#
#   Se thullestHo  eimgsusthy bikfous pild thob diinose thy ere,
#   Bumumy s anty slelgtdariveld wire sT miss lethin nly dageee are hone ir th meohoug urefeir,
#   Yok theilastom sodeld woWnl
# ----
# iter 22000, loss: 18.316375
# ----
#  Ia t
#    iog spente d eill,
#   Whupinets ;ee boge's wh thy thee to:u o  genes ouvest teautheuseanthes barach toch lend sa fheu cart out) ys thow thy gald the premsts,  allOsner calestr'vautuou hos lfmar
# ----
# iter 22100, loss: 18.252369
# ----
#  at thoe wngold thou f
# t hacensamare tho wher tingteutt ise my hekl wn soun rid lrwe pyat thi thoss fiprecineshand anh the burris prans nreaco ere dote thy grofeine ar,
#
#     Th sl wked afiit thant foom
# ----
# iter 22200, loss: 18.204731
# ----
#
#   Anan.
#
#   T s wven
#   Ao  hey tomt lam.
# .
#   O  hi
#    se,
#   Ffpllom w4tleer nye,
#    oullbee tiov  lle,,  Sindp ans rFves not magerele,
#   Bimeka
#    ut of  fini s lle irg aty seredest thee deye
#   WSles
# ----
# iter 22300, loss: 18.213208
# ----
#  en whe deas verd lev maqnst ily tes pnomd dlass and wing aro thrt boldto, wred
#   Aurean tif tor gathathe gombe oO yog he that ngred ous sh'l moganj, mrpthritby tin t
#   we tfen tie wer vel'st ahe fones
# ----
# iter 22400, loss: 18.268395
# ----
#  es the wocty't 'llee tn anf hro le,
#   Bnallog thou dowait deit jeace hou sheo bo thy coed'souistirgsntwith ef ove
#   Thou sactin the aparin eed ren  her ing tinit wost it tinee tho laatow the wookef el
# ----
# iter 22500, loss: 18.267416
# ----
#  eath,'u f.e d
# r  or7
# e  or wo nf in th thoh thor whew tnes lry.
#
#    o   an the toalk, f thenoures porest fpalf
#
#     w  f
#      i m tew try strlgaven fot  ninel Bute tieos  Sik ice thin on thy thin cunb
# ----
# iter 22600, loss: 18.247713
# ----
#  ealindtene st in moray?
#   Ard tho the be'inasts lu hore,
#   F dn teat  fass urist thepnaMsut Fy beruinlnghis thyisthed werAmdstleap each dor meavern's what wels fout dcound,re,
#   Y th thelp prith,  aro
# ----
# iter 22700, loss: 18.212801
# ----
#  Uhthin beasinmh:d why bes the soll n aft me wound ivesanui;  rno5y winp,
#   Line,
#     po my surcerd hechir shee  aote,hind dowm rar sosren thy herito wurasts so f tiee thae woale w at  hale,
#   Ron ther
# ----
# iter 22800, loss: 18.205074
# ----
#  us doalsadid thstent'I  aed
#   T mne wie tomels,
#   Oi'e autanlss lfyhkely with  wallt thoulder xhow crlsf fenire nwstilo mhathelleft
#   o Bhe pre fy her vine of mend:
#   Age enses urep tos wreter susspat
# ----
# iter 22900, loss: 18.126421
# ----
#  doute fit sgild?t rhrighe ouserin thons,
#   So hhy blfaine.
#
#
#    r  he  bus thed, indhe Bungt wey doll thy seathy hoe'st
#   hor ieitedt of ciok, e rilife3l thy wiot  houtsorpHeriehs wat zime te reptrals
# ----
# iter 23000, loss: 18.104184
# ----
#  dnee-teruslr-niggid sreid preac'sb,
#   Thine watr'ow bhou roound'n eoth mege,
#   Fe tine se Rimerwint?  eadqlonNgggesumy dith bear,a the, so:
#
#   Whecilgsund wiith tland shem faza,
#    hL hin thpmristhe'
# ----
# iter 23100, loss: 18.215674
# ----
#  pry pitsond hiu sumafp iagaobe,ud timer -ains
#  f  oa hace ustor deru
# g Thou don int gamley:
#   TTonlderas lThiuit nale hiw thnd therend :av me mitg phe mard seathy th's hot thnu de ou hathig tis mesh b
# ----
# iter 23200, loss: 18.212856
# ----
#  ccreg wiog  on eneds:
#   S haredot phiiv'stdid thle powes kury thins ehithingest ous phaaso slf le thy ben:l woy selr-catsdese dove-unglof ehin thy lolly's mlawhrt  oy theuuren welt tyou ero no soy dhi
# ----
# iter 23300, loss: 18.164449
# ----
#  be ero d re  ot it   sithrev ald thinfef's bes- ied is anveverd il.
#
#     w gh sfst honthees lltmers vaven .e h;  thaut co loveris sh.
#   Toesthe we tey suy sustey sed thi es pup,tey ,
#   w ou dor thit t
# ----
# iter 23400, loss: 18.168109
